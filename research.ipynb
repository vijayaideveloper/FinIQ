# %%
import os
from datetime import datetime
from pathlib import Path

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
from sqlalchemy import create_engine

DATABASE_URL = "sqlite:///./users.db"
IMAGE_FOLDER = "image_dashboards"


engine = create_engine(DATABASE_URL)



income = pd.read_sql_table("income", engine)
expense = pd.read_sql_table("expense", engine)

# %%
income
# Out:
#    id            email      title  amount
# 0   1  vijay@gmail.com      sales  2000.0
# 1   2  vijay@gmail.com  freelance  2000.0
# 2   3  vijay@gmail.com      posts   233.0
